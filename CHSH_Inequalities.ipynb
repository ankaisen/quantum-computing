# %% [markdown]
# 1. Let $A, B, C$ be random binary variables. **Prove that the following inequality holds**
# $$
# \mbox{Pr}[A = 1 \wedge B = 0] + \mbox{Pr}[B = 1 \wedge C = 0] \ge \mbox{Pr}[A = 1 \wedge C = 0].
# $$

# %% [markdown]
# For convenience, denote $A = 1$ as $\mathcal{A}$, $A = 0$ as $\overline{\mathcal{A}}$, and same to $B$ and $C$, the target inequality becomes $$\mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}}\right] + \mbox{Pr}\left[\mathcal{B} \wedge \overline{\mathcal{C}}\right] \ge \mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{C}}\right]$$
# Since probabilities are non negative, we have: $$
# \mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}} \wedge \mathcal{C}\right] + \mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{B} \wedge \overline{\mathcal{C}}\right] \ge 0.
# $$
# By adding $\mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{C}}\right]$ to both sides:
# \begin{align*}
# &\mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}} \wedge \mathcal{C}\right] + \mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{B} \wedge \overline{\mathcal{C}}\right] + \mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{C}}\right] \\
# =\ &\mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}} \wedge \mathcal{C}\right] + \mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{B} \wedge \overline{\mathcal{C}}\right] + \mbox{Pr}\left[\mathcal{A} \wedge \mathcal{B} \wedge \overline{\mathcal{C}}\right] + \mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}} \wedge \overline{\mathcal{C}}\right]\\
# =\ &\left(\mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}} \wedge \mathcal{C}\right]+\mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}} \wedge \overline{\mathcal{C}}\right]\right)+\left(\mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{B} \wedge \overline{\mathcal{C}}\right] + \mbox{Pr}\left[\mathcal{A} \wedge \mathcal{B} \wedge \overline{\mathcal{C}}\right]\right) \\
# =\ &\mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}}\right] + \mbox{Pr}\left[\mathcal{B} \wedge \overline{\mathcal{C}}\right]\\
# \ge\ &\mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{C}}\right]
# \end{align*}

# %% [markdown]
# 2. Using the previous inequality, **prove the following inequality holds**
#
# $$
# \mbox{Pr}[A \neq B] + \mbox{Pr}[B \neq C] \ge \mbox{Pr}[A \neq C].
# $$

# %% [markdown]
# By using same denotion as question 1, we have $$\mbox{Pr}\left[A \neq B\right] = \mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}}\right] + \mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{B}\right],\ \mbox{Pr}[B \neq C]= \mbox{Pr}\left[\mathcal{B} \wedge \overline{\mathcal{C}}\right] + \mbox{Pr}\left[\overline{\mathcal{B}} \wedge \mathcal{C}\right],\ \mbox{Pr}[A \neq C]=\mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{C}}\right] + \mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{C}\right]$$
# From the conclusion of question 1,
# \begin{equation}
# \mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}}\right] + \mbox{Pr}\left[\mathcal{B} \wedge \overline{\mathcal{C}}\right] \ge \mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{C}}\right] \tag{1}
# \end{equation}
# Similarly, by adding $\mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{C}\right]$ to both sides of $\mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{B} \wedge \overline{\mathcal{C}}\right] + \mbox{Pr}\left[\mathcal{A} \wedge \overline{\mathcal{B}} \wedge \mathcal{C}\right] \ge 0$,
# \begin{equation}
# \mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{B}\right] + \mbox{Pr}\left[\mathcal{\overline{B}} \wedge \mathcal{C}\right] \ge \mbox{Pr}\left[\overline{\mathcal{A}} \wedge \mathcal{C}\right] \tag{2}
# \end{equation}
# By adding (1) and (2), we have $\mbox{Pr}\left[A \neq B\right]+ \mbox{Pr}[B \neq C] \ge \mbox{Pr}[A \neq C]$.

# %% [markdown]
# 3. Here, let $A_1$ and $A_2$ be the random binary variables that Alice obtained when performing measurements with the two bases of her choices on a given quantum state, and let $B_1$ and $B_2$ be those of Bob's. **Prove the following inequality** that is derived from the above Bell inequalities imposing that if all quantum states obeys *local realism* then the inequality below must be satisfied.
#
# $$
# \mbox{Prob}[A_2 \neq B_2] - \mbox{Prob}[A_1 \neq B_1] - \mbox{Prob}[A_2 \neq B_1] - \mbox{Prob}[A_1 \neq B_2] \le 0.
# $$

# %% [markdown]
# If all the quantum states obeys local realism, it means that
#
# (1) $A_1$, $A_2$, $B_1$, $B_2$ are independent
#
# (2) One's measurements do not affect the other one's measurements
#
# From the conclusion of question 2, we have
# \begin{align*}
# &\mbox{Prob}\left[A_1 \neq B_1 \right] + \mbox{Prob}\left[A_2 \neq B_1 \right] + \mbox{Pr}\left[A_1 \neq B_2 \right] \\
# \ge\ &\mbox{Prob}\left[A_1 \neq A_2 \right] + \mbox{Pr}\left[A_1 \neq B_2 \right] \\
# \ge\ &\mbox{Prob}\left[A_2 \neq B_2 \right]
# \end{align*}
# which is exactly $\mbox{Prob}[A_2 \neq B_2] - \mbox{Prob}[A_1 \neq B_1] - \mbox{Prob}[A_2 \neq B_1] - \mbox{Prob}[A_1 \neq B_2] \le 0$.

# %% [markdown]
# 4. Let $X_i$ and $Y_j$ be random binary variables such that $X_i = (-1)^{A_i}$ and $Y_j = (-1)^{B_j}$, respectively, for $i,j \in \{1,2\}$. Let $E[X_iY_j]$ be the expected values of the multiplication of random variables $X_i$ and $Y_j$. Then, by using the above CHSH inequality, **prove the following** (which is a different form of CHSH inequality on the expectation of random variables).
# $$
# E[X_1 Y_1] + E[X_1 Y_2] + E[X_2 Y_1] - E[X_2 Y_2] \le 2
# $$

# %% [markdown]
# Denote $\Lambda$ as the measure space of $A_1, A_2, B_1, B_2$,
# \begin{align*}
# &E\left[X_1 Y_1\right] + E\left[X_1 Y_2\right] + E\left[X_2 Y_1 \right] - E\left[X_2 Y_2\right] \\
# =\ &\sum\nolimits_{\Lambda}P_{\Lambda}\cdot X_1 Y_1 + \sum\nolimits_{\Lambda}P_{\Lambda}\cdot X_1 Y_2 + \sum\nolimits_{\Lambda}P_{\Lambda}\cdot X_2 Y_1 -\sum\nolimits_{\Lambda}P_{\Lambda}\cdot X_2 Y_2\\
# =\ &\sum\nolimits_{\Lambda}P_{\Lambda}\cdot\left[X_1(Y_1+Y_2)+X_2(Y_1-Y_2)\right] \tag{3}
# \end{align*}
# Let $T(X_1, X_2, Y_1, Y_2) = X_1(Y_1+Y_2)+X_2(Y_1-Y_2)$
#
# 1. When $B_1=B_2$, $Y_1+Y_2=\pm 2,\ Y_1-Y_2=0 \Rightarrow T=\pm 2$
#
# 2. When $B_1 \neq B_2$, $Y_1+Y_2=0,\ Y_1-Y_2=\pm 2 \Rightarrow T=\pm 2$
#
# Thus $T=\pm 2$, Continue (3): $\sum\nolimits_{\Lambda}P_{\Lambda}\cdot T \le \sum\nolimits_{\Lambda}P_{\Lambda}\cdot 2 =2 $.

# %% [markdown]
# 5. **Show that the following quantum states and measurements of Alice and Bob violate the above CHSH inequality**. First, Alice and Bob share entangled qubits each of which in the following form:
# $$
# \frac{1}{\sqrt{2}} \left( \left|01\right> - \left|10\right> \right).
# $$
# Imagine a quantum state as in the above is shared by Alice (the 1st-qubit) and Bob (the 2nd-qubit). They are free to measure their own qubit with the following measurement settings:
#     * Alice measures with $\{\left|0\right>, \left|1\right>\}$ or $\{\left|+\right>, \left|-\right>\}$.
#     * Bob measures with $\{\cos(\theta) \left|0\right> + \sin(\theta) \left|1\right>, -\sin(\theta) \left|0\right> + \cos(\theta) \left|1\right> \}$ or $\{\sin(\theta)\left|0\right> + \cos(\theta)\left|1\right>, -\cos(\theta)\left|0\right> + \sin(\theta)\left|1\right>\}$.
#     * Plot the value of the following equations with respect to the value of $0 \le \theta \le 2\pi$, and show that there is a range of $\theta$ where the CHSH inequality is violated, namely,
#
#     $$
#     E[X_1 Y_1] + E[X_1 Y_2] + E[X_2 Y_1] - E[X_2 Y_2] > 2
#     $$
#     You can solve it by running quantum simulator and change the value of $\theta$.

# %%
import numpy as np
import math
from qiskit import(
  QuantumCircuit,
  execute,
  Aer)
from qiskit.visualization import plot_histogram

# make quantum circuit
def make_circuit(alice=0, bob=0, theta=0):
    circuit = QuantumCircuit(2, 2)
    # create 1/√2 (|01⟩−|10⟩)
    circuit.x(0)
    circuit.x(1)
    circuit.h(0)
    circuit.cx(0,1)

    if alice == 0:
        # alice |0⟩ |1⟩, do nothing
        pass
    elif alice == 1:
        # alice |+⟩ |-⟩, apply inverse of H rotation = H
        circuit.h(0)
        
    # Ry(a) -> apply [[cos(a/2), - sin(a/2)], [sin(a/2), cos(a/2)] 
    if bob == 0:
        # bob cosθ|0⟩+sinθ|1⟩ -sinθ|0⟩+cosθ|1⟩
        # 
        # Ry(2θ)|0⟩ = cosθ|0⟩ + sinθ|1⟩
        #
        # apply Ry(-2θ) to get the basis back to z axis?
        circuit.ry(-2 * theta, 1)
    elif bob == 1:
        # bob sinθ|0⟩+cosθ|1⟩ -cosθ|0⟩+sinθ|1⟩ 
        # equivalent to 
        # cos(π/2-θ)|0⟩+sin(π/2-θ)|1⟩ -sin(π/2-θ)|0⟩+cos(π/2-θ)|1⟩ 
        #
        # Ry(π-2θ)|0⟩ = cos(π/2-θ)|0⟩ + sin(π/2-θ)|1⟩ = sinθ|0⟩+cosθ|1⟩
        # 
        # apply Ry(2θ - π) to get the basis back to z axis?
        # but the CHSH value seems to be wrong ...
        circuit.ry(2 * theta - np.pi, 1) # if circuit.ry(2 * (theta - np.pi)) is applied, in some point CHSH ≒ 2√2

    circuit.measure([0,1], [0,1])
    return circuit

# calculate expected value
def E(circuit, simulator=Aer.get_backend("qasm_simulator")):
    shots = 10000
    job = execute(circuit, simulator, shots=shots)
    counts = job.result().get_counts()
    probs = []
    # qiskit 00 → equation |00> → XY = 1
    # qiskit 10 → equation |01> → XY = -1
    # qiskit 01 → equation |10> → XY = -1
    # qiskit 11 → equation |11> → XY = 1
    for xy in ["00", "10", "01", "11"]:
        count_xy = counts.get(xy)
        if count_xy is None:
            count_xy = 0
        else:
            count_xy = count_xy / shots # calculate the probability
        probs.append(count_xy)
    return probs[0] - probs[1] - probs[2] + probs[3]

# simulation
for angle in range(360):
    Es = [] # expected value
    for alice in range(2):
        for bob in range(2):
            circuit = make_circuit(alice, bob, math.radians(angle)) # from 0° to 359°
            Es.append(E(circuit))
    CHSH = abs(Es[0] + Es[1] + Es[2] - Es[3]) # CHSH is an absolute value?
    print(f"{angle:3d} {CHSH: 2.3f} {Es[0]: 2.3f} {Es[1]: 2.3f} {Es[2]: 2.3f} {Es[3]: 2.3f}")
# Out:
#   0  0.002 -1.000  1.000  0.016  0.014
#   1  0.004 -0.999  0.999 -0.030 -0.026
#   2  0.004 -0.998  0.998 -0.077 -0.072
#   3  0.003 -0.994  0.995 -0.097 -0.100
#   4  0.014 -0.991  0.989 -0.137 -0.125
#   5  0.001 -0.986  0.986 -0.175 -0.174
#   6  0.008 -0.979  0.977 -0.218 -0.212
#   7  0.000 -0.972  0.968 -0.241 -0.245
#   8  0.024 -0.961  0.963 -0.284 -0.257
#   9  0.002 -0.953  0.955 -0.315 -0.311
#  10  0.004 -0.939  0.939 -0.337 -0.341
#  11  0.002 -0.927  0.933 -0.380 -0.376
#  12  0.016 -0.918  0.910 -0.414 -0.407
#  13  0.002 -0.900  0.897 -0.437 -0.439
#  14  0.001 -0.878  0.882 -0.471 -0.469
#  15  0.007 -0.860  0.863 -0.491 -0.496
#  16  0.021 -0.845  0.841 -0.549 -0.532
#  17  0.014 -0.824  0.832 -0.547 -0.553
#  18  0.006 -0.811  0.812 -0.582 -0.587
#  19  0.013 -0.783  0.788 -0.606 -0.615
#  20  0.019 -0.767  0.753 -0.641 -0.635
#  21  0.013 -0.753  0.750 -0.672 -0.662
#  22  0.014 -0.715  0.722 -0.694 -0.701
#  23  0.005 -0.695  0.686 -0.720 -0.724
#  24  0.005 -0.670  0.667 -0.746 -0.743
#  25  0.016 -0.649  0.628 -0.756 -0.761
#  26  0.001 -0.608  0.614 -0.796 -0.790
#  27  0.003 -0.590  0.584 -0.808 -0.810
#  28  0.012 -0.556  0.560 -0.842 -0.826
#  29  0.015 -0.525  0.533 -0.848 -0.856
#  30  0.012 -0.501  0.499 -0.855 -0.869
#  31  0.024 -0.485  0.469 -0.886 -0.879
#  32  0.003 -0.436  0.437 -0.901 -0.897
#  33  0.022 -0.418  0.392 -0.914 -0.917
#  34  0.004 -0.379  0.379 -0.926 -0.922
#  35  0.027 -0.359  0.336 -0.943 -0.939
#  36  0.030 -0.326  0.298 -0.949 -0.947
#  37  0.003 -0.272  0.268 -0.960 -0.961
#  38  0.007 -0.252  0.257 -0.972 -0.973
#  39  0.005 -0.217  0.211 -0.977 -0.978
#  40  0.022 -0.172  0.193 -0.987 -0.987
#  41  0.002 -0.132  0.128 -0.988 -0.990
#  42  0.041 -0.118  0.076 -0.994 -0.995
#  43  0.001 -0.064  0.064 -0.997 -0.997
#  44  0.015 -0.019  0.033 -1.000 -1.000
#  45  0.003  0.004 -0.002 -1.000 -1.000
#  46  0.004  0.025 -0.021 -1.000 -0.999
#  47  0.024  0.083 -0.058 -0.999 -0.998
#  48  0.026  0.130 -0.102 -0.994 -0.992
#  49  0.019  0.161 -0.142 -0.988 -0.988
#  50  0.005  0.167 -0.160 -0.986 -0.985
#  51  0.027  0.230 -0.204 -0.978 -0.979
#  52  0.011  0.226 -0.233 -0.972 -0.968
#  53  0.015  0.280 -0.265 -0.961 -0.961
#  54  0.025  0.292 -0.316 -0.953 -0.953
#  55  0.005  0.354 -0.347 -0.941 -0.939
#  56  0.014  0.361 -0.381 -0.920 -0.925
# 184  0.007 -0.991  0.992 -0.129 -0.135
# 185  0.009 -0.985  0.986 -0.163 -0.171
# 186  0.031 -0.980  0.978 -0.189 -0.222
# 187  0.002 -0.969  0.973 -0.239 -0.233
# 188  0.022 -0.961  0.961 -0.271 -0.249
# 189  0.022 -0.958  0.954 -0.322 -0.304
# 190  0.013 -0.937  0.940 -0.333 -0.342
# 191  0.008 -0.923  0.928 -0.379 -0.367
# 192  0.002 -0.916  0.913 -0.424 -0.424
# 193  0.001 -0.901  0.902 -0.446 -0.445
# 194  0.007 -0.881  0.891 -0.463 -0.460
# 195  0.012 -0.876  0.865 -0.493 -0.493
# 196  0.008 -0.842  0.846 -0.529 -0.534
# 197  0.014 -0.832  0.824 -0.567 -0.561
# 198  0.003 -0.814  0.817 -0.586 -0.580
# 199  0.021 -0.784  0.779 -0.625 -0.610
# 200  0.002 -0.769  0.766 -0.630 -0.636
# 201  0.013 -0.757  0.734 -0.666 -0.676
# 202  0.005 -0.719  0.718 -0.689 -0.695
# 203  0.004 -0.690  0.699 -0.726 -0.713
# 204  0.009 -0.657  0.661 -0.739 -0.745
# 205  0.009 -0.645  0.644 -0.765 -0.776
# 206  0.001 -0.619  0.619 -0.783 -0.784
# 207  0.007 -0.576  0.591 -0.814 -0.806
# 208  0.009 -0.565  0.554 -0.824 -0.826
# 209  0.019 -0.536  0.520 -0.851 -0.847
# 210  0.004 -0.488  0.493 -0.865 -0.864
# 211  0.013 -0.476  0.464 -0.885 -0.884
# 212  0.004 -0.438  0.436 -0.895 -0.892
# 213  0.018 -0.418  0.398 -0.917 -0.920
# 214  0.005 -0.381  0.372 -0.927 -0.931
# 215  0.022 -0.319  0.340 -0.937 -0.938
# 216  0.007 -0.303  0.314 -0.955 -0.951
# 217  0.030 -0.291  0.267 -0.964 -0.958
# 218  0.012 -0.251  0.237 -0.970 -0.973
# 219  0.011 -0.216  0.206 -0.979 -0.978
# 220  0.002 -0.171  0.169 -0.986 -0.986
# 221  0.003 -0.133  0.134 -0.991 -0.993
# 222  0.020 -0.104  0.084 -0.995 -0.996
# 223  0.006 -0.075  0.069 -0.998 -0.998
# 224  0.008 -0.048  0.056 -0.999 -0.999
# 225  0.008  0.012 -0.005 -1.000 -1.000
# 226  0.020  0.021 -0.041 -0.999 -1.000
# 227  0.014  0.075 -0.062 -0.998 -0.999
# 228  0.012  0.115 -0.103 -0.994 -0.994
# 229  0.019  0.154 -0.135 -0.993 -0.993
# 230  0.005  0.171 -0.178 -0.983 -0.986
# 231  0.032  0.226 -0.195 -0.977 -0.978
# 232  0.000  0.234 -0.238 -0.967 -0.970
# 233  0.002  0.280 -0.278 -0.956 -0.957
# 234  0.002  0.303 -0.296 -0.955 -0.949
# 235  0.021  0.331 -0.350 -0.945 -0.943
# 236  0.005  0.363 -0.372 -0.926 -0.930
# 237  0.003  0.391 -0.395 -0.917 -0.917
# 238  0.002  0.422 -0.433 -0.902 -0.910
# 239  0.019  0.478 -0.468 -0.876 -0.885
# 240  0.013  0.520 -0.510 -0.857 -0.861
# 241  0.006  0.526 -0.523 -0.849 -0.852
# 242  0.002  0.564 -0.559 -0.826 -0.822
# 243  0.019  0.578 -0.596 -0.812 -0.811
# 244  0.020  0.613 -0.623 -0.790 -0.780
# 245  0.004  0.634 -0.639 -0.764 -0.765
# 246  0.014  0.681 -0.669 -0.742 -0.744
# 247  0.028  0.705 -0.688 -0.713 -0.723
# 248  0.004  0.712 -0.720 -0.704 -0.707
# 249  0.018  0.748 -0.736 -0.669 -0.675
# 250  0.004  0.756 -0.765 -0.641 -0.654
# 251  0.004  0.779 -0.787 -0.597 -0.609
# 252  0.034  0.801 -0.821 -0.596 -0.582
# 253  0.006  0.830 -0.827 -0.558 -0.550
# 254  0.001  0.842 -0.844 -0.537 -0.539
# 255  0.006  0.867 -0.864 -0.493 -0.496
# 256  0.005  0.886 -0.887 -0.464 -0.460
# 257  0.023  0.896 -0.898 -0.442 -0.421
# 258  0.008  0.916 -0.909 -0.404 -0.405
# 259  0.001  0.925 -0.931 -0.370 -0.376
# 260  0.002  0.938 -0.935 -0.341 -0.336
# 261  0.010  0.955 -0.952 -0.319 -0.305
# 262  0.002  0.961 -0.963 -0.279 -0.284
# 263  0.002  0.973 -0.974 -0.251 -0.249
# 264  0.026  0.978 -0.980 -0.221 -0.196
# 265  0.008  0.985 -0.984 -0.170 -0.161
# 266  0.024  0.991 -0.989 -0.128 -0.150
# 267  0.001  0.992 -0.996 -0.104 -0.110
# 268  0.004  0.998 -0.998 -0.075 -0.071
# 269  0.010  1.000 -0.999 -0.036 -0.026
# 270  0.024  1.000 -1.000 -0.010  0.015
# 271  0.007  0.999 -0.999  0.032  0.025
# 272  0.005  0.996 -0.997  0.078  0.082
# 273  0.011  0.993 -0.996  0.122  0.109
# 274  0.002  0.991 -0.989  0.145  0.145
# 275  0.011  0.982 -0.984  0.189  0.175
# 276  0.009  0.979 -0.975  0.206  0.219
# 277  0.001  0.973 -0.972  0.231  0.233
# 278  0.035  0.959 -0.965  0.265  0.294
# 279  0.010  0.949 -0.954  0.296  0.302
# 280  0.000  0.938 -0.940  0.335  0.333
# 281  0.005  0.928 -0.927  0.363  0.359
# 282  0.022  0.912 -0.918  0.394  0.410
# 283  0.002  0.901 -0.904  0.447  0.442
# 284  0.014  0.890 -0.878  0.461  0.460
# 285  0.024  0.867 -0.865  0.510  0.487
# 286  0.011  0.841 -0.841  0.536  0.525
# 287  0.013  0.839 -0.829  0.560  0.556
# 288  0.001  0.807 -0.804  0.592  0.594
# 289  0.005  0.797 -0.801  0.627  0.628
# 290  0.042  0.760 -0.770  0.616  0.648
# 291  0.009  0.735 -0.749  0.666  0.662
# 292  0.005  0.715 -0.719  0.695  0.687
# 293  0.000  0.693 -0.705  0.720  0.708
# 294  0.011  0.669 -0.669  0.731  0.741
# 295  0.013  0.645 -0.647  0.752  0.764
# 296  0.010  0.608 -0.607  0.793  0.783
# 297  0.035  0.603 -0.581  0.816  0.803
# 298  0.019  0.544 -0.552  0.827  0.837
# 299  0.008  0.547 -0.543  0.839  0.850
# 300  0.016  0.488 -0.482  0.867  0.857
# 301  0.008  0.460 -0.459  0.877  0.886
# 302  0.001  0.444 -0.436  0.900  0.909
# 303  0.007  0.404 -0.402  0.916  0.911
# 304  0.010  0.392 -0.384  0.929  0.928
# 305  0.006  0.347 -0.341  0.937  0.936
# 306  0.003  0.319 -0.321  0.949  0.950
# 307  0.012  0.266 -0.275  0.962  0.965
# 308  0.005  0.244 -0.245  0.967  0.972
# 309  0.006  0.205 -0.210  0.978  0.980
# 310  0.023  0.181 -0.160  0.985  0.983
# 311  0.008  0.135 -0.143  0.992  0.992
# 312  0.006  0.101 -0.105  0.992  0.994
# 313  0.018  0.056 -0.075  0.998  0.997
# 314  0.018  0.052 -0.033  1.000  1.000
# 315  0.008 -0.007 -0.001  1.000  1.000
# 316  0.000 -0.040  0.040  0.999  1.000
# 317  0.018 -0.068  0.051  0.998  0.999
# 318  0.008 -0.098  0.090  0.994  0.994
# 319  0.015 -0.122  0.135  0.992  0.990
# 320  0.013 -0.170  0.183  0.985  0.985
# 321  0.024 -0.201  0.225  0.982  0.981
# 322  0.005 -0.248  0.250  0.973  0.969
# 323  0.006 -0.270  0.264  0.959  0.959
# 324  0.012 -0.317  0.325  0.953  0.948
# 325  0.002 -0.339  0.337  0.937  0.937
# 326  0.016 -0.374  0.359  0.932  0.932
# 327  0.024 -0.400  0.417  0.919  0.912
# 328  0.003 -0.449  0.452  0.897  0.896
# 329  0.004 -0.475  0.480  0.882  0.883
# 330  0.000 -0.495  0.495  0.860  0.860
# 331  0.001 -0.534  0.535  0.851  0.853
# 332  0.009 -0.552  0.557  0.838  0.834
# 333  0.018 -0.590  0.578  0.806  0.812
# 334  0.001 -0.608  0.625  0.785  0.801
# 335  0.002 -0.637  0.649  0.754  0.764
# 336  0.005 -0.681  0.667  0.746  0.737
# 337  0.002 -0.699  0.695  0.720  0.718
# 338  0.020 -0.725  0.718  0.694  0.707
# 339  0.005 -0.758  0.740  0.677  0.665
# 340  0.021 -0.770  0.757  0.632  0.641
# 341  0.010 -0.787  0.793  0.614  0.611
# 342  0.009 -0.814  0.815  0.596  0.588
# 343  0.011 -0.833  0.833  0.563  0.552
# 344  0.008 -0.848  0.846  0.524  0.530
# 345  0.020 -0.865  0.871  0.515  0.501
# 346  0.002 -0.885  0.883  0.475  0.471
# 347  0.013 -0.900  0.898  0.445  0.430
# 348  0.010 -0.910  0.917  0.410  0.407
# 349  0.014 -0.920  0.928  0.371  0.392
# 350  0.012 -0.935  0.931  0.333  0.341
# 351  0.001 -0.954  0.955  0.310  0.310
# 352  0.010 -0.959  0.957  0.271  0.278
# 353  0.001 -0.967  0.968  0.235  0.236
# 354  0.008 -0.978  0.979  0.213  0.205
# 355  0.004 -0.983  0.982  0.183  0.178
# 356  0.002 -0.989  0.991  0.143  0.144
# 357  0.005 -0.995  0.994  0.107  0.111
# 358  0.005 -0.998  0.998  0.068  0.074
# 359  0.015 -0.999  1.000  0.032  0.018

# %% [markdown]
# 6. **Run experiments that violate the CHSH inequality using publicly-available Noisy Intermediate-Scale Quantum (NISQ) devices**.
#     + Run experiments by using a pair of neighboring qubits in a quantum device. For example, the figure below shows the connectivity of qubits of `ibmq_5_yorktown`. A pair of neighboring qubits is a two-qubit pair connected by an edge, such as the 2-nd qubit (in the middle) with other qubits.
#
#     ![img](data:image/png;base64,...)
#     + Run experiments by using a pair of qubits that are not directly connected in the device. For example, in the device above, the 0-th and 3-rd qubits, or the 1-st and 4-th qubits are not directly connected.
#     + Compare the experimental results and theoretical prediction.
